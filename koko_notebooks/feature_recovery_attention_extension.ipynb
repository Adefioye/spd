# %% [markdown]
# # Feature Recovery: Attention Extension
#
# This notebook covers the attention-only extension from `feature_recovery.md`. It is intentionally lightweight and wraps the existing induction-head experiment stack.

# %%
from pathlib import Path
import subprocess

REPO_ROOT = Path.cwd()
WRAPPER = REPO_ROOT / 'koko_experiments/feature_recovery/run_induction_feature_roles.py'
IH_SPD_CONFIG = REPO_ROOT / 'spd/experiments/ih/ih_config.yaml'

# %% [markdown]
# ## Option A: run SPD on an existing induction-head pretrained model
#
# If `ih_config.yaml` already points at a pretrained run you want, this wrapper just reuses it.

# %%
# subprocess.run(['python', str(WRAPPER), None, str(IH_SPD_CONFIG)], cwd=REPO_ROOT, check=True)
print('Edit the config if you want a different pretrained induction-head run, then uncomment the call.')

# %% [markdown]
# ## Option B: train a fresh small induction model first
#
# Provide a separate induction-head training config and pass it as the first argument to the wrapper. This is the fast route to the functional-role attention experiment described in the research note.
